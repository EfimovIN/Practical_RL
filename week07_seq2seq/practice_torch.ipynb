# %% [markdown]
# ## Reinforcement Learning for seq2seq
#
# This time we'll solve a problem of transribing hebrew words in english, also known as g2p (grapheme2phoneme)
#
#  * word (sequence of letters in source language) -> translation (sequence of letters in target language)
#
# Unlike what most deep learning practicioners do, we won't only train it to maximize likelihood of correct translation, but also employ reinforcement learning to actually teach it to translate with as few errors as possible.
#
#
# ### About the task
#
# One notable property of Hebrew is that it's consonant language. That is, there are no wovels in the written language. One could represent wovels with diacritics above consonants, but you don't expect people to do that in everyay life.
#
# Therefore, some hebrew characters will correspond to several english letters and others - to none, so we should use encoder-decoder architecture to figure that out.
#
# ![img](https://esciencegroup.files.wordpress.com/2016/03/seq2seq.jpg)
# _(img: esciencegroup.files.wordpress.com)_
#
# Encoder-decoder architectures are about converting anything to anything, including
#  * Machine translation and spoken dialogue systems
#  * [Image captioning](http://mscoco.org/dataset/#captions-challenge2015) and [image2latex](https://htmlpreview.github.io/?https://github.com/openai/requests-for-research/blob/master/_requests_for_research/im2latex.html) (convolutional encoder, recurrent decoder)
#  * Generating [images by captions](https://arxiv.org/abs/1511.02793) (recurrent encoder, convolutional decoder)
#  * Grapheme2phoneme - convert words to transcripts
#
# We chose simplified __Hebrew->English__ machine translation for words and short phrases (character-level), as it is relatively quick to train even without a gpu cluster.

# %%
# if running in colab, uncomment
# !wget https://github.com/yandexdataschool/Practical_RL/raw/c54b56049df85315490d1cec42b2fda0c96ad9b2/week07_scst/basic_model_torch.py -O basic_model_torch.py
# !wget https://github.com/yandexdataschool/Practical_RL/raw/c54b56049df85315490d1cec42b2fda0c96ad9b2/week07_scst/main_dataset.txt -O main_dataset.txt
# !wget https://github.com/yandexdataschool/Practical_RL/raw/c54b56049df85315490d1cec42b2fda0c96ad9b2/week07_scst/voc.py -O voc.py
# !pip3 install torch==1.0.0 nltk editdistance

# %%
# If True, only translates phrases shorter than 20 characters (way easier).
EASY_MODE = True
# Useful for initial coding.
# If false, works with all phrases (please switch to this mode for homework assignment)

# way we translate. Either "he-to-en" or "en-to-he"
MODE = "he-to-en"
# maximal length of _generated_ output, does not affect training
MAX_OUTPUT_LENGTH = 50 if not EASY_MODE else 20
REPORT_FREQ = 100                          # how often to evaluate validation score

# %% [markdown]
# ### Step 1: preprocessing
#
# We shall store dataset as a dictionary
# `{ word1:[translation1,translation2,...], word2:[...],...}`.
#
# This is mostly due to the fact that many words have several correct translations.
#
# We have implemented this thing for you so that you can focus on more interesting parts.
#
#
# __Attention python2 users!__ You may want to cast everything to unicode later during homework phase, just make sure you do it _everywhere_.

# %%
import numpy as np
from collections import defaultdict
word_to_translation = defaultdict(list)  # our dictionary

bos = '_'
eos = ';'

with open("main_dataset.txt", encoding="utf-8") as fin:
    for line in fin:

        en, he = line[:-1].lower().replace(bos, ' ').replace(eos,
                                                             ' ').split('\t')
        word, trans = (he, en) if MODE == 'he-to-en' else (en, he)

        if len(word) < 3:
            continue
        if EASY_MODE:
            if max(len(word), len(trans)) > 20:
                continue

        word_to_translation[word].append(trans)

print("size = ", len(word_to_translation))
# Out:
# size =  130113

# %%
# get all unique lines in source language
all_words = np.array(list(word_to_translation.keys()))
# get all unique lines in translation language
all_translations = np.array(
    [ts for all_ts in word_to_translation.values() for ts in all_ts])

# %% [markdown]
# ### split the dataset
#
# We hold out 10% of all words to be used for validation.

# %%
from sklearn.model_selection import train_test_split
train_words, test_words = train_test_split(
    all_words, test_size=0.1, random_state=42)

# %%
list(all_words[0])[::-1]
# Out:
# ['ם', 'ז', 'י', 'כ', 'ר', 'נ', 'א']

# %% [markdown]
# ### Building vocabularies
#
# We now need to build vocabularies that map strings to token ids and vice versa. We're gonna need these fellas when we feed training data into model or convert output matrices into english words.

# %%
from voc import Vocab
inp_voc = Vocab.from_lines(''.join(all_words), bos=bos, eos=eos, sep='')
out_voc = Vocab.from_lines(''.join(all_translations), bos=bos, eos=eos, sep='')

# %%
# Here's how you cast lines into ids and backwards.
batch_lines = all_words[:5]
batch_ids = inp_voc.to_matrix(batch_lines)
batch_lines_restored = inp_voc.to_lines(batch_ids)

print("lines")
print(batch_lines)
print("\nwords to ids (0 = bos, 1 = eos):")
print(batch_ids)
print("\nback to words")
print(batch_lines_restored)
# Out:
# lines
# ['אנרכיזם' 'אוטיזם קלאסי' 'אלבדו' 'אלבמה' 'אכילס']
#
# words to ids (0 = bos, 1 = eos):
# [[  0  37 103  39   8 106 149  78   1   1   1   1   1   1]
#  [  0  37  60 129 106 149  78  98  11  32  37 118 106   1]
#  [  0  37  32 113  52  60   1   1   1   1   1   1   1   1]
#  [  0  37  32 113 173 159   1   1   1   1   1   1   1   1]
#  [  0  37   8 106  32 118   1   1   1   1   1   1   1   1]]
#
# back to words
# ['אנרכיזם', 'אוטיזם קלאסי', 'אלבדו', 'אלבמה', 'אכילס']

# %% [markdown]
# Draw word/translation length distributions to estimate the scope of the task.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=[8, 4])
plt.subplot(1, 2, 1)
plt.title("words")
plt.hist(list(map(len, all_words)), bins=20)

plt.subplot(1, 2, 2)
plt.title('translations')
plt.hist(list(map(len, all_translations)), bins=20)
# Out:
# (array([   21.,   112.,  3098.,  8157., 11482., 12556., 11430.,  9568.,
#          9254.,  9755., 10299., 11123., 11203., 10840.,  9316.,  7873.,
#          6527.,  5523.,  4505.,  3684.]),
#  array([ 1.  ,  1.95,  2.9 ,  3.85,  4.8 ,  5.75,  6.7 ,  7.65,  8.6 ,
#          9.55, 10.5 , 11.45, 12.4 , 13.35, 14.3 , 15.25, 16.2 , 17.15,
#         18.1 , 19.05, 20.  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### Step 3: deploy encoder-decoder (1 point)
#
# __assignment starts here__
#
# Our architecture consists of two main blocks:
# * Encoder reads words character by character and outputs code vector (usually a function of last RNN state)
# * Decoder takes that code vector and produces translations character by character
#
# Than it gets fed into a model that follows this simple interface:
# * __`model(inp, out, **flags) -> logp`__ - takes symbolic int32 matrices of hebrew words and their english translations. Computes the log-probabilities of all possible english characters given english prefices and hebrew word.
# * __`model.translate(inp, **flags) -> out, logp`__ - takes symbolic int32 matrix of hebrew words, produces output tokens sampled from the model and output log-probabilities for all possible tokens at each tick.
#   * if given flag __`greedy=True`__, takes most likely next token at each iteration. Otherwise samples with next token probabilities predicted by model.
#
# That's all! It's as hard as it gets. With those two methods alone you can implement all kinds of prediction and training.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from basic_model_torch import BasicTranslationModel
model = BasicTranslationModel(inp_voc, out_voc,
                              emb_size=64, hid_size=256)

# %%
# Play around with symbolic_translate and symbolic_score
inp = torch.tensor(np.random.randint(0, 10, [3, 5]), dtype=torch.int64)
out = torch.tensor(np.random.randint(0, 10, [3, 5]), dtype=torch.int64)

# translate inp (with untrained model)
sampled_out, logp = model.translate(inp, greedy=False)

print("Sample translations:\n", sampled_out)
print("Log-probabilities at each step:\n", logp)
# Out:
# tensor([True, True, True]) tensor([149, 147, 158]) 1
# tensor([True, True, True]) tensor([269, 282,  23]) 1
# tensor([True, True, True]) tensor([218, 244, 176]) 1
# tensor([True, True, True]) tensor([203, 103,   5]) 1
# tensor([True, True, True]) tensor([ 14,  84, 237]) 1
# tensor([True, True, True]) tensor([237,  58,  83]) 1
# tensor([True, True, True]) tensor([ 38, 170,  75]) 1
# tensor([True, True, True]) tensor([ 34, 237, 170]) 1
# tensor([True, True, True]) tensor([215, 179, 112]) 1
# tensor([True, True, True]) tensor([ 20, 212, 163]) 1
# tensor([True, True, True]) tensor([ 37, 166,  76]) 1
# tensor([True, True, True]) tensor([136, 171, 207]) 1
# tensor([True, True, True]) tensor([ 20, 205, 280]) 1
# tensor([True, True, True]) tensor([186, 147, 180]) 1
# tensor([True, True, True]) tensor([228,  49, 227]) 1
# tensor([True, True, True]) tensor([ 16, 194, 207]) 1
# tensor([True, True, True]) tensor([204, 244, 255]) 1
# tensor([True, True, True]) tensor([214, 253, 105]) 1
# tensor([True, True, True]) tensor([ 76, 250,  37]) 1
# tensor([True, True, True]) tensor([ 94,  89, 267]) 1
# tensor([True, True, True]) tensor([268,  15, 204]) 1
# tensor([True, True, True]) tensor([ 31, 161, 118]) 1
# tensor([True, True, True]) tensor([213, 179, 218]) 1
# tensor([True, True, True]) tensor([ 57, 226, 177]) 1
# tensor([True, True, True]) tensor([158, 132,  95]) 1
# tensor([True, True, True]) tensor([126, 220, 193]) 1
# tensor([True, True, True]) tensor([147, 136, 167]) 1
# tensor([True, True, True]) tensor([183, 176, 272]) 1
# tensor([True, True, True]) tensor([ 95, 165,  11]) 1
# tensor([True, True, True]) tensor([122, 116, 210]) 1
# tensor([True, True, True]) tensor([266, 146,  71]) 1
# tensor([True, True, True]) tensor([214, 217,  59]) 1
# tensor([True, True, True]) tensor([ 84, 191, 213]) 1
# tensor([True, True, True]) tensor([102, 195,  97]) 1
# tensor([True, True, True]) tensor([  5, 206,  27]) 1
# tensor([True, True, True]) tensor([119, 192,  99]) 1
# tensor([True, True, True]) tensor([ 11,   2, 214]) 1
# tensor([True, True, True]) tensor([113,  75,  62]) 1
# tensor([True, True, True]) tensor([ 61, 142, 245]) 1
# tensor([True, True, True]) tensor([260, 276,  87]) 1
# tensor([True, True, True]) tensor([114,  44, 213]) 1
# tensor([True, True, True]) tensor([119,   0, 223]) 1
# tensor([True, True, True]) tensor([158, 236,  33]) 1
# tensor([True, True, True]) tensor([95, 34, 37]) 1
# tensor([True, True, True]) tensor([118,  96, 241]) 1
# tensor([True, True, True]) tensor([151,  95, 201]) 1
# tensor([True, True, True]) tensor([ 67,  53, 236]) 1
# tensor([True, True, True]) tensor([147, 266, 153]) 1
# tensor([True, True, True]) tensor([241, 242, 118]) 1
# tensor([True, True, True]) tensor([ 29, 164, 198]) 1
# tensor([True, True, True]) tensor([166,  69, 282]) 1
# tensor([True, True, True]) tensor([226, 204, 155]) 1
# tensor([True, True, True]) tensor([165, 253,  22]) 1
# tensor([True, True, True]) tensor([48, 14,  4]) 1
# tensor([True, True, True]) tensor([ 36, 265,  29]) 1
# tensor([True, True, True]) tensor([208,  92,  80]) 1
# tensor([True, True, True]) tensor([269, 139, 184]) 1
# tensor([True, True, True]) tensor([ 58, 184, 134]) 1
# tensor([True, True, True]) tensor([218, 264,  52]) 1
# tensor([True, True, True]) tensor([231, 116, 133]) 1
# tensor([True, True, True]) tensor([223, 147,  73]) 1
# tensor([True, True, True]) tensor([111, 160, 140]) 1
# tensor([True, True, True]) tensor([150, 244, 113]) 1
# tensor([True, True, True]) tensor([ 21, 274,  20]) 1
# tensor([True, True, True]) tensor([260, 178, 111]) 1
# tensor([True, True, True]) tensor([ 10,   5, 243]) 1
# tensor([True, True, True]) tensor([ 37, 122, 168]) 1
# tensor([True, True, True]) tensor([128, 136, 209]) 1
# tensor([True, True, True]) tensor([134,  70, 159]) 1
# tensor([True, True, True]) tensor([190, 147, 199]) 1
# tensor([True, True, True]) tensor([18, 24, 28]) 1
# tensor([True, True, True]) tensor([71, 13, 78]) 1
# tensor([True, True, True]) tensor([242,  40,  84]) 1
# tensor([True, True, True]) tensor([157, 276, 257]) 1
# tensor([True, True, True]) tensor([ 17, 169, 275]) 1
# tensor([True, True, True]) tensor([ 49,  67, 143]) 1
# tensor([True, True, True]) tensor([151,  65, 273]) 1
# tensor([True, True, True]) tensor([222,   0, 263]) 1
# tensor([True, True, True]) tensor([122, 120, 274]) 1
# tensor([True, True, True]) tensor([266, 210, 260]) 1
# tensor([True, True, True]) tensor([221, 263,   1]) 1
# tensor([ True,  True, False]) tensor([255, 228, 130]) 1
# tensor([ True,  True, False]) tensor([194, 170, 251]) 1
# tensor([ True,  True, False]) tensor([241, 274, 118]) 1
# tensor([ True,  True, False]) tensor([160, 154,  69]) 1
# tensor([ True,  True, False]) tensor([201, 167, 145]) 1
# tensor([ True,  True, False]) tensor([165, 100,  43]) 1
# tensor([ True,  True, False]) tensor([ 54, 269, 251]) 1
# tensor([ True,  True, False]) tensor([176, 238, 258]) 1
# tensor([ True,  True, False]) tensor([271, 144, 137]) 1
# tensor([ True,  True, False]) tensor([107, 128,  51]) 1
# tensor([ True,  True, False]) tensor([ 46, 108, 222]) 1
# tensor([ True,  True, False]) tensor([22, 15, 70]) 1
# tensor([ True,  True, False]) tensor([58,  9, 34]) 1
# tensor([ True,  True, False]) tensor([ 81,  44, 202]) 1
# tensor([ True,  True, False]) tensor([ 22,  13, 107]) 1
# tensor([ True,  True, False]) tensor([109, 128, 116]) 1
# tensor([ True,  True, False]) tensor([134, 202, 200]) 1
# tensor([ True,  True, False]) tensor([157, 103,  45]) 1
# tensor([ True,  True, False]) tensor([210,  50, 174]) 1
# tensor([ True,  True, False]) tensor([182, 155,   5]) 1
# tensor([ True,  True, False]) tensor([114, 198, 104]) 1
# tensor([ True,  True, False]) tensor([ 67, 185,  45]) 1
# tensor([ True,  True, False]) tensor([204, 279, 217]) 1
# tensor([ True,  True, False]) tensor([166, 280,  17]) 1
# tensor([ True,  True, False]) tensor([257, 182, 129]) 1
# tensor([ True,  True, False]) tensor([108, 142, 270]) 1
# tensor([ True,  True, False]) tensor([110, 226,  35]) 1
# tensor([ True,  True, False]) tensor([152,  65, 141]) 1
# tensor([ True,  True, False]) tensor([241, 275, 214]) 1
# tensor([ True,  True, False]) tensor([ 78, 199,  64]) 1
# tensor([ True,  True, False]) tensor([253, 238, 170]) 1
# tensor([ True,  True, False]) tensor([ 55, 194,   6]) 1
# tensor([ True,  True, False]) tensor([256, 128,   3]) 1
# tensor([ True,  True, False]) tensor([ 91, 174, 247]) 1
# tensor([ True,  True, False]) tensor([ 44, 272, 112]) 1
# tensor([ True,  True, False]) tensor([ 72,  67, 206]) 1
# tensor([ True,  True, False]) tensor([181, 200, 228]) 1
# tensor([ True,  True, False]) tensor([166, 240, 133]) 1
# tensor([ True,  True, False]) tensor([247,  69, 143]) 1
# tensor([ True,  True, False]) tensor([161, 261, 141]) 1
# tensor([ True,  True, False]) tensor([ 30,  43, 253]) 1
# tensor([ True,  True, False]) tensor([164,  35,   0]) 1
# tensor([ True,  True, False]) tensor([124,  62, 261]) 1
# tensor([ True,  True, False]) tensor([193, 108, 141]) 1
# tensor([ True,  True, False]) tensor([ 96, 168, 171]) 1
# tensor([ True,  True, False]) tensor([276, 130,  54]) 1
# tensor([ True,  True, False]) tensor([ 42,  91, 250]) 1
# tensor([ True,  True, False]) tensor([250, 101, 221]) 1
# tensor([ True,  True, False]) tensor([ 41, 278,  26]) 1
# tensor([ True,  True, False]) tensor([217, 180,  31]) 1
# tensor([ True,  True, False]) tensor([232, 196, 199]) 1
# tensor([ True,  True, False]) tensor([ 57, 254,   8]) 1
# tensor([ True,  True, False]) tensor([114,  59, 170]) 1
# tensor([ True,  True, False]) tensor([ 25,  59, 136]) 1
# tensor([ True,  True, False]) tensor([ 49, 229, 202]) 1
# tensor([ True,  True, False]) tensor([221, 123, 119]) 1
# tensor([ True,  True, False]) tensor([142, 208, 191]) 1
# tensor([ True,  True, False]) tensor([ 38, 257, 165]) 1
# tensor([ True,  True, False]) tensor([ 30,  36, 223]) 1
# tensor([ True,  True, False]) tensor([ 67, 279, 245]) 1
# tensor([ True,  True, False]) tensor([195, 170,  43]) 1
# tensor([ True,  True, False]) tensor([192, 200, 222]) 1
# tensor([ True,  True, False]) tensor([240, 198,  52]) 1
# tensor([ True,  True, False]) tensor([173, 169,  66]) 1
# tensor([ True,  True, False]) tensor([221, 173, 276]) 1
# tensor([ True,  True, False]) tensor([ 55,  12, 178]) 1
# tensor([ True,  True, False]) tensor([134, 119, 100]) 1
# tensor([ True,  True, False]) tensor([223, 180, 173]) 1
# tensor([ True,  True, False]) tensor([178,  13, 207]) 1
# tensor([ True,  True, False]) tensor([228,  25, 148]) 1
# tensor([ True,  True, False]) tensor([196,  26, 185]) 1
# tensor([ True,  True, False]) tensor([120,  93, 237]) 1
# tensor([ True,  True, False]) tensor([70, 72, 81]) 1
# tensor([ True,  True, False]) tensor([165,  12, 260]) 1
# tensor([ True,  True, False]) tensor([ 71, 178,  33]) 1
# tensor([ True,  True, False]) tensor([179, 282,  87]) 1
# tensor([ True,  True, False]) tensor([159, 234,  93]) 1
# tensor([ True,  True, False]) tensor([191, 215, 251]) 1
# tensor([ True,  True, False]) tensor([126, 215, 224]) 1
# tensor([ True,  True, False]) tensor([162, 265, 254]) 1
# tensor([ True,  True, False]) tensor([264, 142,  11]) 1
# tensor([ True,  True, False]) tensor([183,  87, 104]) 1
# tensor([ True,  True, False]) tensor([152, 248,   9]) 1
# tensor([ True,  True, False]) tensor([111,  19,  54]) 1
# tensor([ True,  True, False]) tensor([190, 248, 246]) 1
# tensor([ True,  True, False]) tensor([112,  70,  58]) 1
# tensor([ True,  True, False]) tensor([ 44, 129, 186]) 1
# tensor([ True,  True, False]) tensor([271, 162,  81]) 1
# tensor([ True,  True, False]) tensor([180,  43, 232]) 1
# tensor([ True,  True, False]) tensor([ 57, 118, 261]) 1
# tensor([ True,  True, False]) tensor([108, 182, 182]) 1
# tensor([ True,  True, False]) tensor([211, 183,   6]) 1
# tensor([ True,  True, False]) tensor([268, 140,  39]) 1
# tensor([ True,  True, False]) tensor([249, 102, 241]) 1
# tensor([ True,  True, False]) tensor([198,  58, 216]) 1
# tensor([ True,  True, False]) tensor([186,  98, 200]) 1
# tensor([ True,  True, False]) tensor([ 33,  99, 281]) 1
# tensor([ True,  True, False]) tensor([127, 157, 116]) 1
# tensor([ True,  True, False]) tensor([141,  96, 223]) 1
# tensor([ True,  True, False]) tensor([ 73,  23, 199]) 1
# tensor([ True,  True, False]) tensor([155,  22, 236]) 1
# tensor([ True,  True, False]) tensor([167,  20, 184]) 1
# tensor([ True,  True, False]) tensor([256,   2, 227]) 1
# tensor([ True,  True, False]) tensor([217, 116, 130]) 1
# tensor([ True,  True, False]) tensor([121, 111, 158]) 1
# tensor([ True,  True, False]) tensor([262,  23,  10]) 1
# tensor([ True,  True, False]) tensor([  6, 189, 175]) 1
# tensor([ True,  True, False]) tensor([ 28, 139, 140]) 1
# tensor([ True,  True, False]) tensor([ 14,  26, 146]) 1
# tensor([ True,  True, False]) tensor([188, 276, 278]) 1
# tensor([ True,  True, False]) tensor([170, 244, 237]) 1
# tensor([ True,  True, False]) tensor([127,   4, 158]) 1
# tensor([ True,  True, False]) tensor([ 61, 252, 277]) 1
# tensor([ True,  True, False]) tensor([209, 195, 112]) 1
# tensor([ True,  True, False]) tensor([ 91,  68, 203]) 1
# tensor([ True,  True, False]) tensor([174, 251, 234]) 1
# tensor([ True,  True, False]) tensor([246, 120, 240]) 1
# tensor([ True,  True, False]) tensor([131, 227, 219]) 1
# tensor([ True,  True, False]) tensor([229, 212, 181]) 1
# tensor([ True,  True, False]) tensor([113, 272, 204]) 1
# tensor([ True,  True, False]) tensor([186,  72, 196]) 1
# tensor([ True,  True, False]) tensor([ 26,   7, 242]) 1
# tensor([ True,  True, False]) tensor([ 54,  43, 233]) 1
# tensor([ True,  True, False]) tensor([117, 166, 200]) 1
# tensor([ True,  True, False]) tensor([ 49, 163, 245]) 1
# tensor([ True,  True, False]) tensor([276, 125, 225]) 1
# tensor([ True,  True, False]) tensor([117, 241, 271]) 1
# tensor([ True,  True, False]) tensor([162, 171,  98]) 1
# tensor([ True,  True, False]) tensor([219,   1,  99]) 1
# tensor([ True, False, False]) tensor([196, 236, 180]) 1
# tensor([ True, False, False]) tensor([134,  49, 148]) 1
# tensor([ True, False, False]) tensor([243, 106, 102]) 1
# tensor([ True, False, False]) tensor([212, 205,  54]) 1
# tensor([ True, False, False]) tensor([119, 169,  67]) 1
# tensor([ True, False, False]) tensor([ 75, 164, 229]) 1
# tensor([ True, False, False]) tensor([ 93,  46, 260]) 1
# tensor([ True, False, False]) tensor([187,   8, 147]) 1
# tensor([ True, False, False]) tensor([191,  68, 260]) 1
# tensor([ True, False, False]) tensor([94, 92, 70]) 1
# tensor([ True, False, False]) tensor([66, 48, 17]) 1
# tensor([ True, False, False]) tensor([281, 275,  37]) 1
# tensor([ True, False, False]) tensor([114, 275, 111]) 1
# tensor([ True, False, False]) tensor([138, 105, 185]) 1
# tensor([ True, False, False]) tensor([249, 247, 134]) 1
# tensor([ True, False, False]) tensor([ 66, 145, 137]) 1
# tensor([ True, False, False]) tensor([103, 220, 102]) 1
# tensor([ True, False, False]) tensor([208, 276, 150]) 1
# tensor([ True, False, False]) tensor([103, 198, 206]) 1
# tensor([ True, False, False]) tensor([219,   6, 280]) 1
# tensor([ True, False, False]) tensor([135,  73, 191]) 1
# tensor([ True, False, False]) tensor([222, 140, 234]) 1
# tensor([ True, False, False]) tensor([110, 112, 134]) 1
# tensor([ True, False, False]) tensor([217, 122, 266]) 1
# tensor([ True, False, False]) tensor([15, 98, 32]) 1
# tensor([ True, False, False]) tensor([269,  13, 129]) 1
# tensor([ True, False, False]) tensor([111,  47,   6]) 1
# tensor([ True, False, False]) tensor([281, 115,  47]) 1
# tensor([ True, False, False]) tensor([252, 115, 210]) 1
# tensor([ True, False, False]) tensor([282,  75, 130]) 1
# tensor([ True, False, False]) tensor([ 55, 141, 177]) 1
# tensor([ True, False, False]) tensor([177, 156,  94]) 1
# tensor([ True, False, False]) tensor([  0, 247, 117]) 1
# tensor([ True, False, False]) tensor([115, 271, 253]) 1
# tensor([ True, False, False]) tensor([ 36, 147,  22]) 1
# tensor([ True, False, False]) tensor([107, 273, 118]) 1
# tensor([ True, False, False]) tensor([175, 203,  62]) 1
# tensor([ True, False, False]) tensor([129,  57,  13]) 1
# tensor([ True, False, False]) tensor([ 90, 155,  92]) 1
# tensor([ True, False, False]) tensor([ 78, 140, 105]) 1
# tensor([ True, False, False]) tensor([ 18, 103,  44]) 1
# tensor([ True, False, False]) tensor([101,  90, 222]) 1
# tensor([ True, False, False]) tensor([147, 223, 114]) 1
# tensor([ True, False, False]) tensor([264,  55, 100]) 1
# tensor([ True, False, False]) tensor([232, 158, 135]) 1
# tensor([ True, False, False]) tensor([206,  78, 216]) 1
# tensor([ True, False, False]) tensor([274, 255, 274]) 1
# tensor([ True, False, False]) tensor([190, 119, 166]) 1
# tensor([ True, False, False]) tensor([190,  75, 126]) 1
# tensor([ True, False, False]) tensor([268,  13, 200]) 1
# tensor([ True, False, False]) tensor([281, 135, 198]) 1
# tensor([ True, False, False]) tensor([175, 282,  85]) 1
# tensor([ True, False, False]) tensor([155,  40, 276]) 1
# tensor([ True, False, False]) tensor([178, 248, 214]) 1
# tensor([ True, False, False]) tensor([165,  31, 142]) 1
# tensor([ True, False, False]) tensor([274,  78, 282]) 1
# tensor([ True, False, False]) tensor([ 68,  23, 235]) 1
# tensor([ True, False, False]) tensor([280, 240, 226]) 1
# tensor([ True, False, False]) tensor([139,  51,  94]) 1
# tensor([ True, False, False]) tensor([153, 269,   5]) 1
# tensor([ True, False, False]) tensor([58, 16, 63]) 1
# tensor([ True, False, False]) tensor([275,  80,  11]) 1
# tensor([ True, False, False]) tensor([ 30,  64, 163]) 1
# tensor([ True, False, False]) tensor([107, 199,   1]) 1
# tensor([ True, False, False]) tensor([254,   3, 184]) 1
# tensor([ True, False, False]) tensor([181, 230, 182]) 1
# tensor([ True, False, False]) tensor([254,  24,   8]) 1
# tensor([ True, False, False]) tensor([136,  74, 121]) 1
# tensor([ True, False, False]) tensor([163, 267, 182]) 1
# tensor([ True, False, False]) tensor([264, 253, 127]) 1
# tensor([ True, False, False]) tensor([  8, 217, 172]) 1
# tensor([ True, False, False]) tensor([197, 105,  44]) 1
# tensor([ True, False, False]) tensor([180,  50,  58]) 1
# tensor([ True, False, False]) tensor([153,   0, 213]) 1
# tensor([ True, False, False]) tensor([ 44, 167, 215]) 1
# tensor([ True, False, False]) tensor([119,  26, 191]) 1
# tensor([ True, False, False]) tensor([ 50,   5, 276]) 1
# tensor([ True, False, False]) tensor([101, 109, 272]) 1
# tensor([ True, False, False]) tensor([ 48, 104,  97]) 1
# tensor([ True, False, False]) tensor([ 78, 222, 174]) 1
# tensor([ True, False, False]) tensor([240, 260,   0]) 1
# tensor([ True, False, False]) tensor([171,  58, 281]) 1
# tensor([ True, False, False]) tensor([ 49, 221,  31]) 1
# tensor([ True, False, False]) tensor([ 78,  44, 274]) 1
# tensor([ True, False, False]) tensor([ 22,  26, 163]) 1
# tensor([ True, False, False]) tensor([109, 239,  83]) 1
# tensor([ True, False, False]) tensor([ 90, 101, 141]) 1
# tensor([ True, False, False]) tensor([154, 166, 224]) 1
# tensor([ True, False, False]) tensor([149, 276, 209]) 1
# tensor([ True, False, False]) tensor([ 67, 235, 266]) 1
# tensor([ True, False, False]) tensor([ 85, 195, 264]) 1
# tensor([ True, False, False]) tensor([180,  40, 133]) 1
# tensor([ True, False, False]) tensor([103, 106,  23]) 1
# tensor([ True, False, False]) tensor([205,  40, 239]) 1
# tensor([ True, False, False]) tensor([203, 239, 249]) 1
# tensor([ True, False, False]) tensor([ 72, 118, 216]) 1
# tensor([ True, False, False]) tensor([186,  11,  55]) 1
# tensor([ True, False, False]) tensor([111, 246,  16]) 1
# tensor([ True, False, False]) tensor([ 92, 271, 275]) 1
# tensor([ True, False, False]) tensor([233, 273, 144]) 1
# tensor([ True, False, False]) tensor([213, 177,   8]) 1
# tensor([ True, False, False]) tensor([131, 161,   0]) 1
# tensor([ True, False, False]) tensor([264, 191, 117]) 1
# tensor([ True, False, False]) tensor([ 16, 193, 153]) 1
# tensor([ True, False, False]) tensor([93,  4, 74]) 1
# tensor([ True, False, False]) tensor([213,  73, 135]) 1
# tensor([ True, False, False]) tensor([135,  71, 269]) 1
# tensor([ True, False, False]) tensor([ 21,  40, 251]) 1
# tensor([ True, False, False]) tensor([ 86,  25, 186]) 1
# tensor([ True, False, False]) tensor([146,  79, 184]) 1
# tensor([ True, False, False]) tensor([237,  82,  45]) 1
# tensor([ True, False, False]) tensor([143,  13, 129]) 1
# tensor([ True, False, False]) tensor([207, 237,  99]) 1
# tensor([ True, False, False]) tensor([275,  16,  61]) 1
# tensor([ True, False, False]) tensor([256,  30,  25]) 1
# tensor([ True, False, False]) tensor([ 24, 138, 139]) 1
# tensor([ True, False, False]) tensor([202, 199,  72]) 1
# tensor([ True, False, False]) tensor([176, 140, 245]) 1
# tensor([ True, False, False]) tensor([147, 114,  93]) 1
# tensor([ True, False, False]) tensor([  1, 141, 280]) 1
# Sample translations:
#  tensor([[  0, 149, 269, 218, 203,  14, 237,  38,  34, 215,  20,  37, 136,  20,
#          186, 228,  16, 204, 214,  76,  94, 268,  31, 213,  57, 158, 126, 147,
#          183,  95, 122, 266, 214,  84, 102,   5, 119,  11, 113,  61, 260, 114,
#          119, 158,  95, 118, 151,  67, 147, 241,  29, 166, 226, 165,  48,  36,
#          208, 269,  58, 218, 231, 223, 111, 150,  21, 260,  10,  37, 128, 134,
#          190,  18,  71, 242, 157,  17,  49, 151, 222, 122, 266, 221, 255, 194,
#          241, 160, 201, 165,  54, 176, 271, 107,  46,  22,  58,  81,  22, 109,
#          134, 157, 210, 182, 114,  67, 204, 166, 257, 108, 110, 152, 241,  78,
#          253,  55, 256,  91,  44,  72, 181, 166, 247, 161,  30, 164, 124, 193,
#           96, 276,  42, 250,  41, 217, 232,  57, 114,  25,  49, 221, 142,  38,
#           30,  67, 195, 192, 240, 173, 221,  55, 134, 223, 178, 228, 196, 120,
#           70, 165,  71, 179, 159, 191, 126, 162, 264, 183, 152, 111, 190, 112,
#           44, 271, 180,  57, 108, 211, 268, 249, 198, 186,  33, 127, 141,  73,
#          155, 167, 256, 217, 121, 262,   6,  28,  14, 188, 170, 127,  61, 209,
#           91, 174, 246, 131, 229, 113, 186,  26,  54, 117,  49, 276, 117, 162,
#          219, 196, 134, 243, 212, 119,  75,  93, 187, 191,  94,  66, 281, 114,
#          138, 249,  66, 103, 208, 103, 219, 135, 222, 110, 217,  15, 269, 111,
#          281, 252, 282,  55, 177,   0, 115,  36, 107, 175, 129,  90,  78,  18,
#          101, 147, 264, 232, 206, 274, 190, 190, 268, 281, 175, 155, 178, 165,
#          274,  68, 280, 139, 153,  58, 275,  30, 107, 254, 181, 254, 136, 163,
#          264,   8, 197, 180, 153,  44, 119,  50, 101,  48,  78, 240, 171,  49,
#           78,  22, 109,  90, 154, 149,  67,  85, 180, 103, 205, 203,  72, 186,
#          111,  92, 233, 213, 131, 264,  16,  93, 213, 135,  21,  86, 146, 237,
#          143, 207, 275, 256,  24, 202, 176, 147,   1],
#         [  0, 147, 282, 244, 103,  84,  58, 170, 237, 179, 212, 166, 171, 205,
#          147,  49, 194, 244, 253, 250,  89,  15, 161, 179, 226, 132, 220, 136,
#          176, 165, 116, 146, 217, 191, 195, 206, 192,   2,  75, 142, 276,  44,
#            0, 236,  34,  96,  95,  53, 266, 242, 164,  69, 204, 253,  14, 265,
#           92, 139, 184, 264, 116, 147, 160, 244, 274, 178,   5, 122, 136,  70,
#          147,  24,  13,  40, 276, 169,  67,  65,   0, 120, 210, 263, 228, 170,
#          274, 154, 167, 100, 269, 238, 144, 128, 108,  15,   9,  44,  13, 128,
#          202, 103,  50, 155, 198, 185, 279, 280, 182, 142, 226,  65, 275, 199,
#          238, 194, 128, 174, 272,  67, 200, 240,  69, 261,  43,  35,  62, 108,
#          168, 130,  91, 101, 278, 180, 196, 254,  59,  59, 229, 123, 208, 257,
#           36, 279, 170, 200, 198, 169, 173,  12, 119, 180,  13,  25,  26,  93,
#           72,  12, 178, 282, 234, 215, 215, 265, 142,  87, 248,  19, 248,  70,
#          129, 162,  43, 118, 182, 183, 140, 102,  58,  98,  99, 157,  96,  23,
#           22,  20,   2, 116, 111,  23, 189, 139,  26, 276, 244,   4, 252, 195,
#           68, 251, 120, 227, 212, 272,  72,   7,  43, 166, 163, 125, 241, 171,
#            1, 236,  49, 106, 205, 169, 164,  46,   8,  68,  92,  48, 275, 275,
#          105, 247, 145, 220, 276, 198,   6,  73, 140, 112, 122,  98,  13,  47,
#          115, 115,  75, 141, 156, 247, 271, 147, 273, 203,  57, 155, 140, 103,
#           90, 223,  55, 158,  78, 255, 119,  75,  13, 135, 282,  40, 248,  31,
#           78,  23, 240,  51, 269,  16,  80,  64, 199,   3, 230,  24,  74, 267,
#          253, 217, 105,  50,   0, 167,  26,   5, 109, 104, 222, 260,  58, 221,
#           44,  26, 239, 101, 166, 276, 235, 195,  40, 106,  40, 239, 118,  11,
#          246, 271, 273, 177, 161, 191, 193,   4,  73,  71,  40,  25,  79,  82,
#           13, 237,  16,  30, 138, 199, 140, 114, 141],
#         [  0, 158,  23, 176,   5, 237,  83,  75, 170, 112, 163,  76, 207, 280,
#          180, 227, 207, 255, 105,  37, 267, 204, 118, 218, 177,  95, 193, 167,
#          272,  11, 210,  71,  59, 213,  97,  27,  99, 214,  62, 245,  87, 213,
#          223,  33,  37, 241, 201, 236, 153, 118, 198, 282, 155,  22,   4,  29,
#           80, 184, 134,  52, 133,  73, 140, 113,  20, 111, 243, 168, 209, 159,
#          199,  28,  78,  84, 257, 275, 143, 273, 263, 274, 260,   1, 130, 251,
#          118,  69, 145,  43, 251, 258, 137,  51, 222,  70,  34, 202, 107, 116,
#          200,  45, 174,   5, 104,  45, 217,  17, 129, 270,  35, 141, 214,  64,
#          170,   6,   3, 247, 112, 206, 228, 133, 143, 141, 253,   0, 261, 141,
#          171,  54, 250, 221,  26,  31, 199,   8, 170, 136, 202, 119, 191, 165,
#          223, 245,  43, 222,  52,  66, 276, 178, 100, 173, 207, 148, 185, 237,
#           81, 260,  33,  87,  93, 251, 224, 254,  11, 104,   9,  54, 246,  58,
#          186,  81, 232, 261, 182,   6,  39, 241, 216, 200, 281, 116, 223, 199,
#          236, 184, 227, 130, 158,  10, 175, 140, 146, 278, 237, 158, 277, 112,
#          203, 234, 240, 219, 181, 204, 196, 242, 233, 200, 245, 225, 271,  98,
#           99, 180, 148, 102,  54,  67, 229, 260, 147, 260,  70,  17,  37, 111,
#          185, 134, 137, 102, 150, 206, 280, 191, 234, 134, 266,  32, 129,   6,
#           47, 210, 130, 177,  94, 117, 253,  22, 118,  62,  13,  92, 105,  44,
#          222, 114, 100, 135, 216, 274, 166, 126, 200, 198,  85, 276, 214, 142,
#          282, 235, 226,  94,   5,  63,  11, 163,   1, 184, 182,   8, 121, 182,
#          127, 172,  44,  58, 213, 215, 191, 276, 272,  97, 174,   0, 281,  31,
#          274, 163,  83, 141, 224, 209, 266, 264, 133,  23, 239, 249, 216,  55,
#           16, 275, 144,   8,   0, 117, 153,  74, 135, 269, 251, 186, 184,  45,
#          129,  99,  61,  25, 139,  72, 245,  93, 280]])
# Log-probabilities at each step:
#  tensor([[[  0.0000, -69.0776, -69.0776,  ..., -69.0776, -69.0776, -69.0776],
#          [ -5.6494,  -5.4134,  -5.6426,  ...,  -5.7141,  -5.5841,  -5.6109],
#          [ -5.5926,  -5.4433,  -5.6647,  ...,  -5.6392,  -5.6210,  -5.6323],
#          ...,
#          [ -5.5917,  -5.6714,  -5.7978,  ...,  -5.7327,  -5.7162,  -5.5974],
#          [ -5.5844,  -5.5365,  -5.6661,  ...,  -5.7975,  -5.7100,  -5.6815],
#          [ -5.6927,  -5.5678,  -5.6872,  ...,  -5.8790,  -5.6409,  -5.4991]],
#
#         [[  0.0000, -69.0776, -69.0776,  ..., -69.0776, -69.0776, -69.0776],
#          [ -5.6939,  -5.4003,  -5.6152,  ...,  -5.7725,  -5.6547,  -5.6387],
#          [ -5.7373,  -5.5204,  -5.6733,  ...,  -5.8957,  -5.6170,  -5.4623],
#          ...,
#          [ -5.6751,  -5.6428,  -5.7080,  ...,  -5.7360,  -5.5270,  -5.6742],
#          [ -5.6334,  -5.5855,  -5.6410,  ...,  -5.6357,  -5.4826,  -5.6930],
#          [ -5.5828,  -5.5693,  -5.6582,  ...,  -5.6569,  -5.4679,  -5.6300]],
#
#         [[  0.0000, -69.0776, -69.0776,  ..., -69.0776, -69.0776, -69.0776],
#          [ -5.6073,  -5.4090,  -5.6469,  ...,  -5.7358,  -5.6098,  -5.5961],
#          [ -5.5920,  -5.5523,  -5.6285,  ...,  -5.6516,  -5.7023,  -5.4956],
#          ...,
#          [ -5.5576,  -5.5906,  -5.3947,  ...,  -5.5372,  -5.5887,  -5.6883],
#          [ -5.6258,  -5.6747,  -5.5542,  ...,  -5.5717,  -5.5216,  -5.7014],
#          [ -5.6936,  -5.5582,  -5.7115,  ...,  -5.7215,  -5.5002,  -5.6927]]],
#        grad_fn=<LogSoftmaxBackward>)

# %%
x = np.array([10,20,30]) 
x &= 1 == np.array([1,2,3])
x
# Out:
# array([0, 0, 0])

# %%
1 == np.array([1,2,3])
# Out:
# array([ True, False, False])

# %%
bool(1)
# Out:
# True

# %%
x=0
x &= True!=False
x
# Out:
# 0

# %%
# score logp(out | inp) with untrained input
logp = model(inp, out)
print("Symbolic_score output:\n", logp)

print("Log-probabilities of output tokens:\n",
      torch.gather(logp, dim=2, index=out[:, :, None]))
# Out:
# Symbolic_score output:
#  tensor([[[  0.0000, -69.0776, -69.0776,  ..., -69.0776, -69.0776, -69.0776],
#          [ -5.6087,  -5.7168,  -5.6908,  ...,  -5.7493,  -5.6974,  -5.6282],
#          [ -5.6997,  -5.6195,  -5.6178,  ...,  -5.8373,  -5.7222,  -5.5610],
#          [ -5.6561,  -5.6579,  -5.6493,  ...,  -5.7892,  -5.8310,  -5.5594],
#          [ -5.5491,  -5.6317,  -5.5859,  ...,  -5.9172,  -5.7495,  -5.4974]],
#
#         [[  0.0000, -69.0776, -69.0776,  ..., -69.0776, -69.0776, -69.0776],
#          [ -5.7422,  -5.6835,  -5.6804,  ...,  -5.6835,  -5.7476,  -5.6126],
#          [ -5.5696,  -5.6324,  -5.6109,  ...,  -5.7483,  -5.7567,  -5.7252],
#          [ -5.5356,  -5.6748,  -5.5689,  ...,  -5.6505,  -5.5990,  -5.5750],
#          [ -5.4862,  -5.7557,  -5.6509,  ...,  -5.5870,  -5.6906,  -5.6253]],
#
#         [[  0.0000, -69.0776, -69.0776,  ..., -69.0776, -69.0776, -69.0776],
#          [ -5.5481,  -5.6660,  -5.4630,  ...,  -5.6654,  -5.5659,  -5.7096],
#          [ -5.6789,  -5.5899,  -5.5021,  ...,  -5.8029,  -5.6597,  -5.6012],
#          [ -5.8301,  -5.6270,  -5.6458,  ...,  -5.7446,  -5.7153,  -5.5763],
#          [ -5.7100,  -5.6502,  -5.6743,  ...,  -5.7407,  -5.8223,  -5.5684]]],
#        grad_fn=<LogSoftmaxBackward>)
# Log-probabilities of output tokens:
#  tensor([[[-69.0776],
#          [ -5.7168],
#          [ -5.6667],
#          [ -5.6474],
#          [ -5.5942]],
#
#         [[-69.0776],
#          [ -5.4625],
#          [ -5.6057],
#          [ -5.5616],
#          [ -5.6938]],
#
#         [[  0.0000],
#          [ -5.6660],
#          [ -5.5951],
#          [ -5.6534],
#          [ -5.6743]]], grad_fn=<GatherBackward>)

# %%
def translate(lines, max_len=MAX_OUTPUT_LENGTH):
    """
    You are given a list of input lines. 
    Make your neural network translate them.
    :return: a list of output lines
    """
    # Convert lines to a matrix of indices
    lines_ix = inp_voc.to_matrix(lines)
    lines_ix = torch.tensor(lines_ix, dtype=torch.int64)

    # Compute translations in form of indices
    trans_ix, _ = model.translate(inp, greedy=True)

    # Convert translations back into strings
    return out_voc.to_lines(trans_ix.data.numpy())

# %%
print("Sample inputs:", all_words[:3])
print("Dummy translations:", translate(all_words[:3]))
trans = translate(all_words[:3])

assert translate(all_words[:3]) == translate(
    all_words[:3]), "make sure translation is deterministic (use greedy=True and disable any noise layers)"
assert type(translate(all_words[:3])) is list and (type(translate(all_words[:1])[0]) is str or type(
    translate(all_words[:1])[0]) is unicode), "translate(lines) must return a sequence of strings!"
# note: if translation freezes, make sure you used max_len parameter
print("Tests passed!")
# Out:
# Sample inputs: ['אנרכיזם' 'אוטיזם קלאסי' 'אלבדו']
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# Dummy translations: ['ьn子כככככככככעăīəăīəטn', 'ьn', '熊dաíňấľ']
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# Tests passed!

# %% [markdown]
# ### Scoring function
#
# LogLikelihood is a poor estimator of model performance.
# * If we predict zero probability once, it shouldn't ruin entire model.
# * It is enough to learn just one translation if there are several correct ones.
# * What matters is how many mistakes model's gonna make when it translates!
#
# Therefore, we will use minimal Levenshtein distance. It measures how many characters do we need to add/remove/replace from model translation to make it perfect. Alternatively, one could use character-level BLEU/RougeL or other similar metrics.
#
# The catch here is that Levenshtein distance is not differentiable: it isn't even continuous. We can't train our neural network to maximize it by gradient descent.

# %%
import editdistance  # !pip install editdistance


def get_distance(word, trans):
    """
    A function that takes word and predicted translation
    and evaluates (Levenshtein's) edit distance to closest correct translation
    """
    references = word_to_translation[word]
    assert len(references) != 0, "wrong/unknown word"
    return min(editdistance.eval(trans, ref) for ref in references)


def score(words, bsize=100):
    """a function that computes levenshtein distance for bsize random samples"""
    assert isinstance(words, np.ndarray)

    batch_words = np.random.choice(words, size=bsize, replace=False)
    batch_trans = translate(batch_words)

    distances = list(map(get_distance, batch_words, batch_trans))

    return np.array(distances, dtype='float32')

# %%
# should be around 5-50 and decrease rapidly after training :)
[score(test_words, 10).mean() for _ in range(5)]
# Out:
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# tensor([True, True, True]) tensor([85, 85, 10]) 1
# tensor([True, True, True]) tensor([111, 111, 104]) 1
# tensor([True, True, True]) tensor([114,   1, 172]) 1
# tensor([ True, False,  True]) tensor([ 11, 281, 227]) 1
# tensor([ True, False,  True]) tensor([ 11,  28, 259]) 1
# tensor([ True, False,  True]) tensor([ 11, 172,  94]) 1
# tensor([ True, False,  True]) tensor([ 11, 172, 277]) 1
# tensor([ True, False,  True]) tensor([ 11, 189,   1]) 1
# tensor([ True, False, False]) tensor([ 11, 129, 101]) 1
# tensor([ True, False, False]) tensor([ 11, 217,  13]) 1
# tensor([ True, False, False]) tensor([ 11,  35, 214]) 1
# tensor([ True, False, False]) tensor([11, 15, 76]) 1
# tensor([ True, False, False]) tensor([214, 124, 111]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 124,  11]) 1
# tensor([ True, False, False]) tensor([213,  60,  11]) 1
# tensor([ True, False, False]) tensor([13, 15, 11]) 1
# tensor([ True, False, False]) tensor([189, 179,  11]) 1
# tensor([ True, False, False]) tensor([213, 185,  11]) 1
# tensor([ True, False, False]) tensor([193, 251,  11]) 1
# tensor([ True, False, False]) tensor([111,  42,  11]) 1
# tensor([ True, False, False]) tensor([  1, 177, 214]) 1
# [14.333333, 11.0, 13.666667, 12.0, 13.666667]

# %% [markdown]
# ## Step 2: Supervised pre-training (2 points)
#
# Here we define a function that trains our model through maximizing log-likelihood a.k.a. minimizing crossentropy.

# %%
import random


def sample_batch(words, word_to_translation, batch_size):
    """
    sample random batch of words and random correct translation for each word
    example usage:
    batch_x,batch_y = sample_batch(train_words, word_to_translations,10)
    """
    # choose words
    batch_words = np.random.choice(words, size=batch_size)

    # choose translations
    batch_trans_candidates = list(map(word_to_translation.get, batch_words))
    batch_trans = list(map(random.choice, batch_trans_candidates))
    return batch_words, batch_trans

# %%
bx, by = sample_batch(train_words, word_to_translation, batch_size=3)
print("Source:")
print(bx)
print("Target:")
print(by)
# Out:
# Source:
# ['פרנק פראזטה' '1107' 'סלין']
# Target:
# ['frank frazetta', '1107', 'celine']

# %%
from basic_model_torch import infer_length, infer_mask, to_one_hot


def compute_loss_on_batch(input_sequence, reference_answers):
    """ Compute crossentropy loss given a batch of sources and translations """
    input_sequence = torch.tensor(inp_voc.to_matrix(input_sequence), dtype=torch.int64)
    reference_answers = torch.tensor(out_voc.to_matrix(reference_answers), dtype=torch.int64)

    # Compute log-probabilities of all possible tokens at each step. Use model interface.
    logprobs_seq =  # YOUR CODE

    # compute elementwise crossentropy as negative log-probabilities of reference_answers.
    crossentropy = - \
        torch.sum(logprobs_seq *
                  to_one_hot(reference_answers, len(out_voc)), dim=-1)
    assert crossentropy.dim(
    ) == 2, "please return elementwise crossentropy, don't compute mean just yet"

    # average with mask
    mask = infer_mask(reference_answers, out_voc.eos_ix)
    loss = torch.sum(crossentropy * mask) / torch.sum(mask)

    return loss
# Out:
#   File "<ipython-input-94-d2d75114f0cc>", line 10
#     logprobs_seq =  # YOUR CODE
#                                ^
# SyntaxError: invalid syntax

# %%
# test it
loss = compute_loss_on_batch(*sample_batch(train_words, word_to_translation, 3))
print('loss = ', loss)

assert loss.item() > 0.0
loss.backward()
for w in model.parameters():
    assert w.grad is not None and torch.max(torch.abs(w.grad)).item() != 0, \
        "Loss is not differentiable w.r.t. a weight with shape %s. Check comput_loss_on_batch." % (
            w.size(),)

# %% [markdown]
# ##### Actually train the model
#
# Minibatches and stuff...

# %%
from IPython.display import clear_output
from tqdm import tqdm, trange  # or use tqdm_notebook,tnrange

loss_history = []
editdist_history = []
entropy_history = []
opt = torch.optim.Adam(model.parameters())

# %%
for i in trange(25000):
    loss = compute_loss_on_batch(*sample_batch(train_words, word_to_translation, 32))

    # train with backprop
    loss.backward()
    opt.step()
    opt.zero_grad()

    loss_history.append(loss.item())

    if (i+1) % REPORT_FREQ == 0:
        clear_output(True)
        current_scores = score(test_words)
        editdist_history.append(current_scores.mean())
        print("llh=%.3f, mean score=%.3f" %
              (np.mean(loss_history[-10:]), np.mean(editdist_history[-10:])))
        plt.figure(figsize=(12, 4))
        plt.subplot(131)
        plt.title('train loss / traning time')
        plt.plot(loss_history)
        plt.grid()
        plt.subplot(132)
        plt.title('val score distribution')
        plt.hist(current_scores, bins=20)
        plt.subplot(133)
        plt.title('val score / traning time (lower is better)')
        plt.plot(editdist_history)
        plt.grid()
        plt.show()

# %% [markdown]
# __How to interpret the plots:__
#
# * __Train loss__ - that's your model's crossentropy over minibatches. It should go down steadily. Most importantly, it shouldn't be NaN :)
# * __Val score distribution__ - distribution of translation edit distance (score) within batch. It should move to the left over time.
# * __Val score / training time__ - it's your current mean edit distance. This plot is much whimsier than loss, but make sure it goes below 8 by 2500 steps.
#
# If it doesn't, first try to re-create both model and opt. You may have changed it's weight too much while debugging. If that doesn't help, it's debugging time.

# %%
for word in train_words[:10]:
    print("%s -> %s" % (word, translate([word])[0]))

# %%
test_scores = []
for start_i in trange(0, len(test_words), 32):
    batch_words = test_words[start_i:start_i+32]
    batch_trans = translate(batch_words)
    distances = list(map(get_distance, batch_words, batch_trans))
    test_scores.extend(distances)

print("Supervised test score:", np.mean(test_scores))

# %% [markdown]
# ## Self-critical policy gradient (2 points)
#
# In this section you'll implement algorithm called self-critical sequence training (here's an [article](https://arxiv.org/abs/1612.00563)).
#
# The algorithm is a vanilla policy gradient with a special baseline.
#
# $$ \nabla J = E_{x \sim p(s)} E_{y \sim \pi(y|x)} \nabla log \pi(y|x) \cdot (R(x,y) - b(x)) $$
#
# Here reward R(x,y) is a __negative levenshtein distance__ (since we minimize it). The baseline __b(x)__ represents how well model fares on word __x__.
#
# In practice, this means that we compute baseline as a score of greedy translation, $b(x) = R(x,y_{greedy}(x)) $.
#
# ![img](https://github.com/yandexdataschool/Practical_RL/raw/master/yet_another_week/_resource/scheme.png)
#
#
# Luckily, we already obtained the required outputs: `model.greedy_translations, model.greedy_mask` and we only need to compute levenshtein using `compute_levenshtein` function.

# %%
def compute_reward(input_sequence, translations):
    """ computes sample-wise reward given token ids for inputs and translations """
    distances = list(map(get_distance,
                         inp_voc.to_lines(input_sequence.data.numpy()),
                         out_voc.to_lines(translations.data.numpy())))
    # use negative levenshtein distance so that larger reward means better policy
    return - torch.tensor(distances, dtype=torch.int64)

# %%
def scst_objective_on_batch(input_sequence, max_len=MAX_OUTPUT_LENGTH):
    """ Compute pseudo-loss for policy gradient given a batch of sources """
    input_sequence = torch.tensor(inp_voc.to_matrix(input_sequence), dtype=torch.int64)

    # use model to __sample__ symbolic translations given input_sequence
    sample_translations, sample_logp =  # YOUR CODE
    # use model to __greedy__ symbolic translations given input_sequence
    greedy_translations, greedy_logp =  # YOUR CODE

    # compute rewards and advantage
    rewards = compute_reward(input_sequence, sample_translations)
    baseline = <compute __negative__ levenshtein for greedy mode >

    # compute advantage using rewards and baseline
    advantage =  # YOUR CODE

    # compute log_pi(a_t|s_t), shape = [batch, seq_length]
    logp_sample = # YOUR CODE
    
    # ^-- hint: look at how crossentropy is implemented in supervised learning loss above
    # mind the sign - this one should not be multiplied by -1 :)

    # policy gradient pseudo-loss. Gradient of J is exactly policy gradient.
    J = logp_sample * advantage[:, None]

    assert J.dim() == 2, "please return elementwise objective, don't compute mean just yet"

    # average with mask
    mask = infer_mask(sample_translations, out_voc.eos_ix)
    loss = - torch.sum(J * mask) / torch.sum(mask)

    # regularize with negative entropy. Don't forget the sign!
    # note: for entropy you need probabilities for all tokens (sample_logp), not just logp_sample
    entropy = <compute entropy matrix of shape[batch, seq_length], H = -sum(p*log_p), don't forget the sign!>
    # hint: you can get sample probabilities from sample_logp using math :)

    assert entropy.dim(
    ) == 2, "please make sure elementwise entropy is of shape [batch,time]"

    reg = - 0.01 * torch.sum(entropy * mask) / torch.sum(mask)

    return loss + reg, torch.sum(entropy * mask) / torch.sum(mask)

# %% [markdown]
# # Policy gradient training

# %%
entropy_history = [np.nan] * len(loss_history)
opt = torch.optim.Adam(model.parameters(), lr=1e-5)

# %%
for i in trange(100000):
    loss, ent = scst_objective_on_batch(
        sample_batch(train_words, word_to_translation, 32)[0])  # [0] = only source sentence

    # train with backprop
    loss.backward()
    opt.step()
    opt.zero_grad()

    loss_history.append(loss.item())
    entropy_history.append(ent.item())

    if (i+1) % REPORT_FREQ == 0:
        clear_output(True)
        current_scores = score(test_words)
        editdist_history.append(current_scores.mean())
        plt.figure(figsize=(12, 4))
        plt.subplot(131)
        plt.title('val score distribution')
        plt.hist(current_scores, bins=20)
        plt.subplot(132)
        plt.title('val score / traning time')
        plt.plot(editdist_history)
        plt.grid()
        plt.subplot(133)
        plt.title('policy entropy / traning time')
        plt.plot(entropy_history)
        plt.grid()
        plt.show()
        print("J=%.3f, mean score=%.3f" %
              (np.mean(loss_history[-10:]), np.mean(editdist_history[-10:])))

# %% [markdown]
# __Debugging tips:__
# <img src=https://github.com/yandexdataschool/Practical_RL/raw/master/yet_another_week/_resource/do_something_scst.png width=400>
#
#  * As usual, don't expect improvements right away, but in general the model should be able to show some positive changes by 5k steps.
#  * Entropy is a good indicator of many problems.
#    * If it reaches zero, you may need greater entropy regularizer.
#    * If it has rapid changes time to time, you may need gradient clipping.
#    * If it oscillates up and down in an erratic manner... it's perfectly okay for entropy to do so. But it should decrease at the end.
#
#  * We don't show loss_history cuz it's uninformative for pseudo-losses in policy gradient. However, if something goes wrong you can check it to see if everything isn't a constant zero.

# %% [markdown]
# ### Results

# %%
for word in train_words[:10]:
    print("%s -> %s" % (word, translate([word])[0]))

# %%
test_scores = []
for start_i in trange(0, len(test_words), 32):
    batch_words = test_words[start_i:start_i+32]
    batch_trans = translate(batch_words)
    distances = list(map(get_distance, batch_words, batch_trans))
    test_scores.extend(distances)
print("Supervised test score:", np.mean(test_scores))

# ^^ If you get Out Of MemoryError, please replace this with batched computation

# %% [markdown]
# ## Step 6: Make it actually work (5++ pts)
#
# In this section we want you to finally __restart with EASY_MODE=False__ and experiment to find a good model/curriculum for that task.
#
# We recommend you to start with the following architecture
#
# ```
# encoder---decoder
#
#            P(y|h)
#              ^
#  LSTM  ->   LSTM
#   ^          ^
#  biLSTM  ->   LSTM
#   ^          ^
# input       y_prev
# ```
#
# __Note:__ you can fit all 4 state tensors of both LSTMs into a in a single state - just assume that it contains, for example, [h0, c0, h1, c1] - pack it in encode and update in decode.
#
#
# Here are some cool ideas on what you can do then.
#
# __General tips & tricks:__
# * You will likely need to adjust pre-training time for such a network.
# * Supervised pre-training may benefit from clipping gradients somehow.
# * SCST may indulge a higher learning rate in some cases and changing entropy regularizer over time.
# * It's often useful to save pre-trained model parameters to not re-train it every time you want new policy gradient parameters.
# * When leaving training for nighttime, try setting REPORT_FREQ to a larger value (e.g. 500) not to waste time on it.
#
# __Formal criteria:__
# To get 5 points we want you to build an architecture that:
# * _doesn't consist of single GRU_
# * _works better_ than single GRU baseline.
# * We also want you to provide either learning curve or trained model, preferably both
# * ... and write a brief report or experiment log describing what you did and how it fared.
#
# ### Attention
# There's more than one way to connect decoder to encoder
#   * __Vanilla:__ layer_i of encoder last state goes to layer_i of decoder initial state
#   * __Every tick:__ feed encoder last state _on every iteration_ of decoder.
#   * __Attention:__ allow decoder to "peek" at one (or several) positions of encoded sequence on every tick.
#
# The most effective (and cool) of those is, of course, attention.
# You can read more about attention [in this nice blog post](https://distill.pub/2016/augmented-rnns/). The easiest way to begin is to use "soft" attention with "additive" or "dot-product" intermediate layers.
#
# __Tips__
# * Model usually generalizes better if you no longer allow decoder to see final encoder state
# * Once your model made it through several epochs, it is a good idea to visualize attention maps to understand what your model has actually learned
#
# * There's more stuff [here](https://github.com/yandexdataschool/Practical_RL/blob/master/week8_scst/bonus.ipynb)
# * If you opted for hard attention, we recommend [gumbel-softmax](https://blog.evjang.com/2016/11/tutorial-categorical-variational.html) instead of sampling. Also please make sure soft attention works fine before you switch to hard.
#
# ### UREX
# * This is a way to improve exploration in policy-based settings. The main idea is that you find and upweight under-appreciated actions.
# * Here's [video](https://www.youtube.com/watch?v=fZNyHoXgV7M&feature=youtu.be&t=3444)
#  and an [article](https://arxiv.org/abs/1611.09321).
# * You may want to reduce batch size 'cuz UREX requires you to sample multiple times per source sentence.
# * Once you got it working, try using experience replay with importance sampling instead of (in addition to) basic UREX.
#
# ### Some additional ideas:
# * (advanced deep learning) It may be a good idea to first train on small phrases and then adapt to larger ones (a.k.a. training curriculum).
# * (advanced nlp) You may want to switch from raw utf8 to something like unicode or even syllables to make task easier.
# * (advanced nlp) Since hebrew words are written __with vowels omitted__, you may want to use a small Hebrew vowel markup dataset at `he-pron-wiktionary.txt`.

# %%
assert not EASY_MODE, "make sure you set EASY_MODE = False at the top of the notebook."

# %% [markdown]
# `[your report/log here or anywhere you please]`

# %% [markdown]
# __Contributions:__ This notebook is brought to you by
# * Yandex [MT team](https://tech.yandex.com/translate/)
# * Denis Mazur ([DeniskaMazur](https://github.com/DeniskaMazur)), Oleg Vasilev ([Omrigan](https://github.com/Omrigan/)), Dmitry Emelyanenko ([TixFeniks](https://github.com/tixfeniks)) and Fedor Ratnikov ([justheuristic](https://github.com/justheuristic/))
# * Dataset is parsed from [Wiktionary](https://en.wiktionary.org), which is under CC-BY-SA and GFDL licenses.
